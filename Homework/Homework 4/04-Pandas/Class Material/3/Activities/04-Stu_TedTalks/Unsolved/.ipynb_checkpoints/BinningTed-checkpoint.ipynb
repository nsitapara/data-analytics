# %%
# Import Dependencies
import pandas as pd

# %%
# Create a path to the csv and read it into a Pandas DataFrame
csv_path = "Resources/ted_talks.csv"
ted_df = pd.read_csv(csv_path)

ted_df.head(100)
# Out:
#     comments                                        description  duration  \
# 0       4553  Sir Ken Robinson makes an entertaining and pro...      1164
# 1        265  With the same humor and humanity he exuded in ...       977
# 2        124  New York Times columnist David Pogue takes aim...      1286
# 3        200  In an emotionally charged talk, MacArthur-winn...      1116
# 4        593  You've never seen data presented like this. Wi...      1190
# 5        672  Tony Robbins discusses the "invisible forces" ...      1305
# 6        919  When two young Mormon missionaries knock on Ju...       992
# 7         46  Architect Joshua Prince-Ramus takes the audien...      1198
# 8        852  Philosopher Dan Dennett calls for religion -- ...      1485
# 9        900  Pastor Rick Warren, author of "The Purpose-Dri...      1262
# 10        79  Accepting his 2006 TED Prize, Cameron Sinclair...      1414
# 11        55  Jehane Noujaim unveils her 2006 TED Prize wish...      1538
# 12        71  Accepting the 2006 TED Prize, Dr. Larry Brilli...      1550
# 13       242  Jeff Han shows off a cheap, scalable multi-tou...       527
# 14        99  Nicholas Negroponte, founder of the MIT Media ...      1057
# 15       325  Violinist Sirena Huang gives a technically bri...      1481
# 16       305  Pianist and composer Jennifer Lin gives a magi...      1445
# 17        88  Fumes from indoor cooking fires kill more than...       906
# 18       163  Designer Ross Lovegrove expounds his philosoph...      1170
# 19        84  Jimmy Wales recalls how he assembled "a ragtag...      1201
# 20       108  In 2006, open-learning visionary Richard Baran...      1114
# 21       185  Performer and web toymaker Ze Frank delivers a...      1136
# 22        50  The founding mother of the blog revolution, Mo...      1006
# 23       556  Anthropologist Helen Fisher takes on a tricky ...      1407
# 24       117  Eve Ensler, creator of "The Vagina Monologues,...      1225
# 25       184  Legendary scientist David Deutsch puts theoret...      1140
# 26       507  Biologist Richard Dawkins makes a case for "th...      1316
# 27        95  "Freakonomics" author Steven Levitt presents n...      1275
# 28       355  "Tipping Point" author Malcolm Gladwell gets i...      1050
# 29       970  Dan Gilbert, author of "Stumbling on Happiness...      1276
# ..       ...                                                ...       ...
# 70       130  Inventor Dean Kamen lays out his argument for ...      1207
# 71        49  Scientific discoveries, futurist Juan Enriquez...      1340
# 72        86  Graphic designer Stefan Sagmeister takes the a...       930
# 73       107  Worldchanging.com founder Alex Steffen argues ...      1054
# 74        50  Architect Thom Mayne has never been one to tak...      1240
# 75        78  American designer Chris Bangle explains his ph...      1204
# 76        40  Nora York gives a stunning performance of her ...       276
# 77        27  Showing a series of inspiring, unusual and pla...       850
# 78        84  Vik Muniz makes art from pretty much anything,...       891
# 79       131  Oxford philosopher and transhumanist Nick Bost...      1012
# 80       127  In this inspiring talk about recent developmen...      1399
# 81        34  Genomics pioneer Craig Venter takes a break fr...      1011
# 82        47  Engineer and artist Golan Levin pushes the bou...       893
# 83       335  Savage-Rumbaugh's work with bonobo apes, which...      1045
# 84       143  In this stunning slideshow, celebrated nature ...       977
# 85        57  Biologist Sheila Patek talks about her work me...       985
# 86        39  A happy song about global warming, from Jill S...       163
# 87        34  Caroline Lavelle plays the cello like a sorcer...       459
# 88       501  Philosopher Dan Dennett makes a compelling arg...      1308
# 89       296  In this soaring demonstration, deaf percussion...      1929
# 90       231  Green-minded architect and designer William Mc...      1205
# 91        58  The dot-com boom and bust is often compared to...      1031
# 92        58  Rives recaps the most memorable moments of TED...       251
# 93        75  Singer/songwriter Eddi Reader performs "Kitefl...       378
# 94        50  Singer/songwriter Eddi Reader performs "What Y...       312
# 95       588  In the days following the tragic South Asian t...      1172
# 96      6404  Richard Dawkins urges all atheists to openly s...      1750
# 97        49  Satirist Tom Rielly delivers a wicked parody o...      1195
# 98        39  Featuring the vocals and mischievous bell-play...       201
# 99        42  Chris Anderson, then the editor of Wired, expl...       858
#
#              event  languages           main_speaker  \
# 0          TED2006         60           Ken Robinson
# 1          TED2006         43                Al Gore
# 2          TED2006         26            David Pogue
# 3          TED2006         35          Majora Carter
# 4          TED2006         48           Hans Rosling
# 5          TED2006         36           Tony Robbins
# 6          TED2006         31          Julia Sweeney
# 7          TED2006         19    Joshua Prince-Ramus
# 8          TED2006         32            Dan Dennett
# 9          TED2006         31            Rick Warren
# 10         TED2006         27       Cameron Sinclair
# 11         TED2006         20         Jehane Noujaim
# 12         TED2006         24        Larry Brilliant
# 13         TED2006         27               Jeff Han
# 14         TED2006         25    Nicholas Negroponte
# 15         TED2006         31           Sirena Huang
# 16         TED2004         32           Jennifer Lin
# 17         TED2006         27              Amy Smith
# 18         TED2005         22         Ross Lovegrove
# 19  TEDGlobal 2005         32            Jimmy Wales
# 20         TED2006         27       Richard Baraniuk
# 21         TED2004         26               Ze Frank
# 22         TED2006         20             Mena Trott
# 23         TED2006         33           Helen Fisher
# 24         TED2004         23             Eve Ensler
# 25  TEDGlobal 2005         29          David Deutsch
# 26  TEDGlobal 2005         36        Richard Dawkins
# 27         TED2004         25          Steven Levitt
# 28         TED2004         37       Malcolm Gladwell
# 29         TED2004         43            Dan Gilbert
# ..             ...        ...                    ...
# 70         TED2002         18             Dean Kamen
# 71         TED2003         20          Juan Enriquez
# 72         TED2004         26      Stefan Sagmeister
# 73  TEDGlobal 2005         32           Alex Steffen
# 74         TED2005         16             Thom Mayne
# 75         TED2002         23           Chris Bangle
# 76   TEDSalon 2006         28              Nora York
# 77  TEDGlobal 2005         24           Paul Bennett
# 78         TED2003         23              Vik Muniz
# 79  TEDGlobal 2005         24           Nick Bostrom
# 80         TED2005         24          Janine Benyus
# 81  TEDGlobal 2005         21           Craig Venter
# 82         TED2004         20            Golan Levin
# 83         TED2004         28  Susan Savage-Rumbaugh
# 84         TED2005         30          Frans Lanting
# 85         TED2004         18           Sheila Patek
# 98                                   "La Vie en Rose"    443180
# 99                             Technology's long tail    904520
#
# [100 rows x 9 columns]

# %%
# Figure out the minimum and maximum views for a TED Talk
maxviews = ted_df["views"].max()
minviews = ted_df["views"].min()

print("Max Views: " + str(maxviews))
print("Min Views: " + str(minviews))

maxloc = ted_df.loc[ted_df["views"] == ted_df["views"].max()]
minloc = ted_df.loc[ted_df["views"] == ted_df["views"].min()]

maxloc.head()
# minloc.head()
# Out:
# Max Views: 47227110
# Min Views: 50443
#    comments                                        description  duration  \
# 0      4553  Sir Ken Robinson makes an entertaining and pro...      1164
#
#      event  languages  main_speaker  \
# 0  TED2006         60  Ken Robinson
#
#                                         name                        title  \
# 0  Ken Robinson: Do schools kill creativity?  Do schools kill creativity?
#
#       views View Group
# 0  47227110   5m-50mil

# %%
# Create bins in which to place values based upon TED Talk views
bins = [0, 50000, 500000, 5000000,50000000]

# Create labels for these bins
labels_for_bins =["0 to 50k", "50k to 500k","500k-5m","5m-50mil"]

# %%
# Slice the data and place it into bins

sliced_data = pd.cut(ted_df["views"],bins, labels = labels_for_bins)

sliced_data.head()
# Out:
# 0    5m-50mil
# 1     500k-5m
# 2     500k-5m
# 3     500k-5m
# 4    5m-50mil
# Name: views, dtype: category
# Categories (4, object): [0 to 50k < 50k to 500k < 500k-5m < 5m-50mil]

# %%
# Place the data series into a new column inside of the DataFrame

ted_df["View Group"] = sliced_data

ted_df.head()
# Out:
#    comments                                        description  duration  \
# 0      4553  Sir Ken Robinson makes an entertaining and pro...      1164
# 1       265  With the same humor and humanity he exuded in ...       977
# 2       124  New York Times columnist David Pogue takes aim...      1286
# 3       200  In an emotionally charged talk, MacArthur-winn...      1116
# 4       593  You've never seen data presented like this. Wi...      1190
#
#      event  languages   main_speaker  \
# 0  TED2006         60   Ken Robinson
# 1  TED2006         43        Al Gore
# 2  TED2006         26    David Pogue
# 3  TED2006         35  Majora Carter
# 4  TED2006         48   Hans Rosling
#
#                                             name  \
# 0      Ken Robinson: Do schools kill creativity?
# 1           Al Gore: Averting the climate crisis
# 2                  David Pogue: Simplicity sells
# 3             Majora Carter: Greening the ghetto
# 4  Hans Rosling: The best stats you've ever seen
#
#                              title     views View Group
# 0      Do schools kill creativity?  47227110   5m-50mil
# 1      Averting the climate crisis   3200520    500k-5m
# 2                 Simplicity sells   1636292    500k-5m
# 3              Greening the ghetto   1697550    500k-5m
# 4  The best stats you've ever seen  12005869   5m-50mil

# %%
# Create a GroupBy object based upon "View Group"
grouped_data = ted_df.groupby("View Group")


# Find how many rows fall into each bin

howmanyrows = grouped_data["comments"].count()

print(howmanyrows)
# Get the average of each column within the GroupBy object

average = grouped_data["comments","languages","duration"].mean()

print(average)
# Out:
# View Group
# 0 to 50k          0
# 50k to 500k     279
# 500k-5m        2172
# 5m-50mil         99
# Name: comments, dtype: int64
#                comments  languages    duration
# View Group
# 0 to 50k            NaN        NaN         NaN
# 50k to 500k   89.745520  18.763441  833.261649
# 500k-5m      183.727440  27.837017  823.009669
# 5m-50mil     650.393939  40.252525  884.282828

# %%
ted_df.dtypes
# Out:
# comments           int64
# description       object
# duration           int64
# event             object
# languages          int64
# main_speaker      object
# name              object
# title             object
# views              int64
# View Group      category
# dtype: object
