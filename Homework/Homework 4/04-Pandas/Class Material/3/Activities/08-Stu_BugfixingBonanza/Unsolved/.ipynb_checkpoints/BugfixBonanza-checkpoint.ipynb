# %%
import pandas as pd

# %%
# Create a reference to the CSV and import it into a Pandas DataFrame
csv_path = "Resources/EclipseBugs.csv"
pd.read_csv(csv_path)
# Out:
#       Bug\nID   Product        Component       Assignee    Status Resolution  \
# 0        3638       JDT               UI        aeschli  VERIFIED      FIXED
# 1        3854       JDT               UI        aeschli  VERIFIED      FIXED
# 2        4188       JDT               UI        aeschli  VERIFIED      FIXED
# 3        5115       JDT            Debug        aeschli  VERIFIED      FIXED
# 4        5820       JDT               UI        aeschli  VERIFIED      FIXED
# 5        6441       JDT               UI        aeschli  VERIFIED      FIXED
# 6        7329       JDT               UI        aeschli  VERIFIED      FIXED
# 7        7966       JDT               UI        aeschli  VERIFIED      FIXED
# 8        8224       JDT               UI        aeschli  VERIFIED      FIXED
# 9        8280       JDT               UI        aeschli  VERIFIED      FIXED
# 10      10929       JDT               UI        aeschli  VERIFIED      FIXED
# 11      24911       JDT               UI        aeschli  VERIFIED      FIXED
# 12      30991       JDT               UI        aeschli  VERIFIED      FIXED
# 13      32831       JDT               UI        aeschli  VERIFIED      FIXED
# 14      43518       JDT               UI        aeschli  VERIFIED      FIXED
# 15      44425       JDT               UI        aeschli  VERIFIED      FIXED
# 16     188521  Platform  User Assistance       agarcher  VERIFIED      FIXED
# 17       6341       JDT               UI        akiezun  VERIFIED      FIXED
# 18       7046       JDT               UI        akiezun  VERIFIED      FIXED
# 19       7317       JDT               UI        akiezun  VERIFIED      FIXED
# 20       7639       JDT               UI        akiezun  VERIFIED      FIXED
# 21       7873       JDT               UI        akiezun  VERIFIED      FIXED
# 22       8023       JDT               UI        akiezun  VERIFIED      FIXED
# 23       8129       JDT               UI        akiezun  VERIFIED      FIXED
# 24       8730       JDT               UI        akiezun  VERIFIED      FIXED
# 25      11424       JDT               UI        akiezun  VERIFIED      FIXED
# 26      16283  Platform          Compare        akiezun  VERIFIED      FIXED
# 27      18071       JDT               UI        akiezun  VERIFIED      FIXED
# 28      18079       JDT               UI        akiezun  VERIFIED      FIXED
# 29      18276       JDT               UI        akiezun  VERIFIED      FIXED
# ...       ...       ...              ...            ...       ...        ...
# 9970    66058  Platform              Ant  darin.eclipse  VERIFIED      FIXED
# 9971    66417       JDT            Debug  darin.eclipse  VERIFIED      FIXED
# 9972    66453       JDT            Debug  darin.eclipse  VERIFIED      FIXED
# 9973    66576  Platform            Debug  darin.eclipse  VERIFIED      FIXED
# 9974    66867  Platform            Debug  darin.eclipse  VERIFIED      FIXED
# 9975    67463  Platform            Debug  darin.eclipse  VERIFIED      FIXED
# 9976    68132  Platform              Ant  darin.eclipse  VERIFIED      FIXED
# 9977    68621  Platform            Debug  darin.eclipse  VERIFIED      FIXED
# 9978    68808  Platform            Debug  darin.eclipse  VERIFIED      FIXED
# 9979    68809       JDT            Debug  darin.eclipse  VERIFIED      FIXED
# 9980    68840  Platform              Ant  darin.eclipse  VERIFIED      FIXED
# 9981    69083  Platform            Debug  darin.eclipse  VERIFIED      FIXED
# 9982    69235  Platform              Ant  darin.eclipse  VERIFIED      FIXED
# 9983    69736       JDT            Debug  darin.eclipse  VERIFIED      FIXED
# 9984    69815  Platform            Debug  darin.eclipse  VERIFIED      FIXED
# 9985    69818       JDT            Debug  darin.eclipse  VERIFIED      FIXED
# 9986    70238  Platform              Ant  darin.eclipse  VERIFIED      FIXED
# 9987    70472  Platform            Debug  darin.eclipse  VERIFIED      FIXED
# 9988    70492  Platform            Debug  darin.eclipse  VERIFIED      FIXED
# 9989    70493  Platform            Debug  darin.eclipse  VERIFIED      FIXED
# 9990    70495  Platform            Debug  darin.eclipse  VERIFIED      FIXED
# 9991    70499  Platform            Debug  darin.eclipse  VERIFIED      FIXED
# 9992    70629       JDT            Debug  darin.eclipse  VERIFIED      FIXED
# 9993    70664  Platform            Debug  darin.eclipse  VERIFIED      FIXED
# 9994    70841  Platform              Ant  darin.eclipse  VERIFIED      FIXED
# 9995    70864  Platform            Debug  darin.eclipse  VERIFIED      FIXED
# 9996    70955       JDT            Debug  darin.eclipse  VERIFIED      FIXED
# 9997    71149  Platform            Debug  darin.eclipse  VERIFIED      FIXED
# 9998    71292  Platform            Debug  darin.eclipse  VERIFIED      FIXED
# 9999    71296  Platform              Ant  darin.eclipse  VERIFIED      FIXED
#
#                                                 Summary           Changed  \
# 0     Package Viewer: order resource folders before ...    1/17/2002 7:28
# 1                Wrong execution's classpath. (1GEY0W0)    1/18/2002 4:02
# 2                        type hierachy - typo (1GJW2XJ)    1/28/2002 3:12
# 3     Workspace source locator fails with mulitple p...  11/13/2001 10:11
# 4       Close all editors brings up hierarchy of object  11/20/2001 16:22
# 5         "Plugins containing only Jars" logis reverted    1/16/2002 2:58
# 6     Outline view: wrong spelling "Add JavDoc Comment"    1/15/2002 5:56
# 7          Class Creation Dialog generates syntax error    3/28/2002 5:43
# 8     Organize imports adds explicit import to wildc...    2/13/2002 8:38
# 9         Package view back/forward/up arrow hover help    2/13/2002 7:51
# 10             All types cache is flushed to frequently    3/20/2002 8:18
# 11    quick fix: NPE on 'change visibility to defaul...   11/14/2002 9:01
# 12                       NPE in New Java Project Wizard   2/24/2003 10:28
# 13            NPE buildpaths.CPVariableElement.equals()   3/19/2003 10:43
# 14    Stepping through session bean is very slow in ...   10/17/2003 5:27
# 15    Illegal code in the code formatter preference ...   10/8/2003 17:44
# 16    [Webapp] Test F1: 2)  Standalone infocenter no...    6/11/2007 9:50
# 17                 NullPointerException from ReorgGroup    1/16/2002 2:31
# 18    NPE trying to show context menu on method in O...    1/15/2002 6:14
# 19                       ClassCastException during move    1/15/2002 5:53
# 20                   NPE when renaming a local variable    2/13/2002 8:29
# 21                                 Bogus error messages    3/28/2002 5:22
# 22    coreexception when draging packages to its own...    2/13/2002 6:29
# 23                        NPE in Extract Local Variable    3/28/2002 6:49
# 24                 wrong method deleted (packages view)   3/28/2002 10:39
# 25    ArrayIndexOutOfBoundsException at "Expand Sele...    3/28/2002 4:00
# 26            Add from Local History items are unsorted     6/3/2002 6:38
# 27                   Package Viewer: Too many refreshes     6/5/2002 7:47
# 28    We must guard our Action against a Java editor...     6/3/2002 6:32
# 29    Java Search action set is missing the name for...     6/3/2002 6:24
# ...                                                 ...               ...
# 9970             Change project builder "handle" format   6/10/2004 17:55
# 9971  VMDisconnectedException logged from source lookup  10/28/2004 13:54
# 9972  String concatenation gives unexpected result i...   11/8/2004 16:55
# 9973  perspectives pref page tab does not take activ...   2/10/2006 14:36
# 9974                                    icon allignment   6/15/2004 16:25
# 9975               Launch Shortcuts schema is incorrect   6/17/2004 12:43
# 9976  [Readme] How to build with buildfiles that con...    8/5/2004 11:18
# 9977  Invalid thread access in launcher from Checkou...  11/11/2004 16:12
# 9978  all debug actions (step, terminate, etc), shou...    8/5/2004 11:13
# 9979         Support for breakpoints in 1.5 source code   11/9/2004 18:22
# 9980  Source not found on Console hyperlink for Sepa...    1/5/2005 19:24
# 9981     Switch to associated perspective on suspension   11/1/2004 10:41
# 9982               Fully qualify the Ant partition name    8/6/2004 17:38
# 9983  IWAV0138E Remote VM terminated too soon error ...   9/30/2004 11:44
# 9984  DBCS -- System console cannot display Unicode ...   11/1/2004 10:14
# 9985                   NPE when launching with Debugger   7/21/2004 17:32
# 9986  Clicking junit call stack items doesn't open s...   1/17/2005 11:14
# 9987        MemoryBlockManager has redundant null check   7/22/2004 10:40
# 9988           Possible NPE in AddSourceContainerDialog   7/22/2004 10:43
# 9989               Possible NPE in ViewTabCursorManager   7/22/2004 10:49
# 9990                 Redundant null check in RefreshTab   7/22/2004 10:51
# 9991  Unnecessary null check in ContextualLaunchActi...   7/22/2004 10:53
# 9992     [J2SE 5] JDI support for extensible connectors   12/3/2004 15:03
# 9993  TVT3.0:   Improper characters combination "Run...  12/20/2004 12:32
# 9994                                  Move to Ant 1.6.2    4/26/2005 2:43
# 9995     API method to show the console view has a bug.   8/20/2004 14:42
# 9996   Empty string as a program argument not accepted.  10/29/2004 10:27
# 9997  [artwork] When breakpoints are disabled (skipp...   1/14/2005 17:06
# 9998               Launch name is truncated in MRU list   8/20/2004 15:00
# 9999     Ant editor performance tests: opening / typing   10/15/2004 9:30
#
#      Assignee\nReal\nName Classification  ...  Number of\nComments  \
# 0      Martin Aeschlimann        Eclipse  ...                    3
# 1      Martin Aeschlimann        Eclipse  ...                    5
# 2      Martin Aeschlimann        Eclipse  ...                    3
# 3      Martin Aeschlimann        Eclipse  ...                   10
# 4      Martin Aeschlimann        Eclipse  ...                    5
# 5      Martin Aeschlimann        Eclipse  ...                    2
# 6      Martin Aeschlimann        Eclipse  ...                    2
# 7      Martin Aeschlimann        Eclipse  ...                    4
# 8      Martin Aeschlimann        Eclipse  ...                    4
# 9      Martin Aeschlimann        Eclipse  ...                    7
# 10     Martin Aeschlimann        Eclipse  ...                    6
# 11     Martin Aeschlimann        Eclipse  ...                    5
# 12     Martin Aeschlimann        Eclipse  ...                    5
# 13     Martin Aeschlimann        Eclipse  ...                    5
# 14     Martin Aeschlimann        Eclipse  ...                   14
# 15     Martin Aeschlimann        Eclipse  ...                    9
# 16            Adam Archer        Eclipse  ...                   15
# 17            Adam Kiezun        Eclipse  ...                    2
# 18            Adam Kiezun        Eclipse  ...                    2
# 19            Adam Kiezun        Eclipse  ...                    2
# 20            Adam Kiezun        Eclipse  ...                    3
# 21            Adam Kiezun        Eclipse  ...                    5
# 22            Adam Kiezun        Eclipse  ...                    6
# 23            Adam Kiezun        Eclipse  ...                    3
# 24            Adam Kiezun        Eclipse  ...                    4
# 25            Adam Kiezun        Eclipse  ...                    5
# 26            Adam Kiezun        Eclipse  ...                    8
# 27            Adam Kiezun        Eclipse  ...                    8
# 28            Adam Kiezun        Eclipse  ...                    5
# 29            Adam Kiezun        Eclipse  ...                    5
# ...                   ...            ...  ...                  ...
# 9970         Darin Wright        Eclipse  ...                   15
# 9971         Darin Wright        Eclipse  ...                    6
# 9972         Darin Wright        Eclipse  ...                    7
# 9973         Darin Wright        Eclipse  ...                   14
# 9974         Darin Wright        Eclipse  ...                    5
# 9975         Darin Wright        Eclipse  ...                    7
# 9976         Darin Wright        Eclipse  ...                    4
# 9977         Darin Wright        Eclipse  ...                    5
# 9978         Darin Wright        Eclipse  ...                   11
# 9979         Darin Wright        Eclipse  ...                    5
# 9980         Darin Wright        Eclipse  ...                   15
# 9981         Darin Wright        Eclipse  ...                   17
# 9982         Darin Wright        Eclipse  ...                    4
# 9983         Darin Wright        Eclipse  ...                   19
# 9984         Darin Wright        Eclipse  ...                   18
# 9985         Darin Wright        Eclipse  ...                   11
# 9986         Darin Wright        Eclipse  ...                   14
# 9987         Darin Wright        Eclipse  ...                    3
# 9988         Darin Wright        Eclipse  ...                    3
# 9989         Darin Wright        Eclipse  ...                    4
# 9990         Darin Wright        Eclipse  ...                    4
# 9991         Darin Wright        Eclipse  ...                    3
# 9992         Darin Wright        Eclipse  ...                    6
# 9993         Darin Wright        Eclipse  ...                   13
# 9994         Darin Wright        Eclipse  ...                    9
# 9995         Darin Wright        Eclipse  ...                    4
# 9996         Darin Wright        Eclipse  ...                   10
# 9997         Darin Wright        Eclipse  ...                   17
# 9998         Darin Wright        Eclipse  ...                    7
# 9999         Darin Wright        Eclipse  ...                    5
#
#                 Opened            OS Priority         Reporter  \
# 0     10/10/2001 22:58    Windows NT       P1          aeschli
# 1     10/10/2001 23:01    Windows NT       P1      david_audel
# 2     10/10/2001 23:07  Windows 2000       P1      erich_gamma
# 3     10/19/2001 13:41  Windows 2000       P1    darin.eclipse
# 4     11/12/2001 18:18  Windows 2000       P1     jed.anderson
# 5     11/29/2001 13:50  Windows 2000       P1      erich_gamma
# 6        1/8/2002 2:44    Windows NT       P1    daniel_megert
# 7      1/21/2002 15:42  Windows 2000       P1      Tod_Creasey
# 8      1/23/2002 13:42         other       P1     knut_radloff
# 9      1/23/2002 15:25  Windows 2000       P1       jeff_brown
# 10       3/7/2002 4:45  Windows 2000       P1      erich_gamma
# 11     10/17/2002 5:56  Windows 2000       P1          akiezun
# 12      2/5/2003 12:51    Windows XP       P1        csmclaren
# 13     2/24/2003 17:12   Linux-Motif       P1          airvine
# 14     9/23/2003 11:52  Windows 2000       P1         stevenyj
# 15      10/8/2003 9:07  Windows 2000       P1  Olivier_Thomann
# 16     5/22/2007 20:12           All       P1          mpawlow
# 17     11/27/2001 5:58  Windows 2000       P1          aeschli
# 18    12/18/2001 10:49         other       P1          eclipse
# 19      1/7/2002 14:05  Windows 2000       P1         fraenkel
# 20     1/15/2002 14:44  Windows 2000       P1     Ian_Petersen
# 21     1/17/2002 17:37    Windows NT       P1       lynne_kues
# 22     1/22/2002 12:32  Windows 2000       P1          aeschli
# 23     1/23/2002 10:12  Windows 2000       P1          aeschli
# 24      1/30/2002 5:35  Windows 2000       P1          akiezun
# 25     3/14/2002 20:16  Windows 2000       P1             rele
# 26     5/17/2002 13:29  Windows 2000       P1       nick_edgar
# 27     5/28/2002 12:16  Windows 2000       P1          aeschli
# 28     5/28/2002 13:13  Windows 2000       P1     dirk_baeumer
# 29      5/30/2002 0:32  Windows 2000       P1       nick_edgar
# ...                ...           ...      ...              ...
# 9970    6/7/2004 18:43           All       P3      jared_burns
# 9971    6/9/2004 16:48  Windows 2000       P3     saumit.sheth
# 9972    6/9/2004 23:03  Windows 2000       P3       nick_edgar
# 9973   6/10/2004 15:43           All       P3         curtispd
# 9974   6/13/2004 10:57    Windows XP       P3    darin.eclipse
# 9975   6/16/2004 11:09    Windows XP       P3            dejan
# 9976   6/21/2004 21:53    Windows XP       P3    Darin_Swanson
# 9977   6/25/2004 11:06    Windows XP       P3         valentam
# 9978   6/28/2004 15:03    Windows XP       P3    darin.eclipse
# 9979   6/28/2004 15:05    Windows XP       P3    darin.eclipse
# 9980    6/29/2004 5:20    Windows XP       P3       rsontowski
# 9981   6/30/2004 17:29           All       P3      mikhailkhod
# 9982    7/2/2004 23:16    Windows XP       P3    Darin_Swanson
# 9983    7/9/2004 11:56    Windows XP       P3            ying1
# 9984    7/12/2004 5:33    Windows XP       P3          xjhuang
# 9985    7/12/2004 7:02    Windows XP       P3       jfrantzius
# 9986   7/16/2004 11:27  Windows 2000       P3             user
# 9987   7/20/2004 15:38           All       P3      jared_burns
# 9988   7/20/2004 18:08           All       P3      jared_burns
# 9989   7/20/2004 18:13           All       P3      jared_burns
# 9990   7/20/2004 18:18           All       P3      jared_burns
# 9991   7/20/2004 18:32           All       P3      jared_burns
# 9992   7/22/2004 11:23    Windows XP       P3    darin.eclipse
# 9993   7/22/2004 13:45         Linux       P3           dwhare
# 9994   7/26/2004 14:20    Windows XP       P3    Darin_Swanson
# 9995   7/26/2004 18:11    Windows XP       P3         bagrodia
# 9996    7/28/2004 3:29    Windows NT       P3       paul.smith
# 9997    7/30/2004 7:59    Windows XP       P3         acuretra
# 9998    8/3/2004 11:11    Windows XP       P3      dj.houghton
# 9999    8/3/2004 11:41    Windows XP       P3    Darin_Swanson
#
#          Reporter\nReal\nName     Severity Target\nMilestone Version Votes
# 0          Martin Aeschlimann        major               ---       2     0
# 1                 David Audel       normal               ---       2     0
# 2                 Erich Gamma       normal               ---       2     0
# 3                Darin Wright       normal               ---       2     0
# 4                Jed Anderson       normal               ---       2     0
# 5                 Erich Gamma       normal               ---       2     0
# 6                 Dani Megert       normal               ---       2     0
# 7                 Tod Creasey       normal               ---       2     0
# 8                Knut Radloff       normal               ---       2     0
# 9                  Jeff Brown       normal               ---       2     0
# 10                Erich Gamma       normal            2.0 M4       2     0
# 11                Adam Kiezun        major            2.1 M3       2     0
# 12              Chris McLaren     critical           2.1 RC1     2.1     0
# 13              Andrew Irvine       normal           2.1 RC2     2.1     0
# 14                 Steven Jin     critical             2.1.2   2.1.1     0
# 15            Olivier Thomann      blocker            3.0 M4       3     0
# 16             Mike Pawlowski       normal           3.3 RC2     3.3     0
# 17         Martin Aeschlimann       normal               ---       2     0
# 18            Joe Szurszewski       normal               ---       2     0
# 19           Michael Fraenkel       normal               ---       2     0
# 20               Ian Petersen       normal               ---       2     0
# 21                 Lynne Kues       normal               ---       2     0
# 22         Martin Aeschlimann        major               ---       2     0
# 23         Martin Aeschlimann       normal               ---       2     0
# 24                Adam Kiezun        major               ---       2     0
# 25             Rene Leonhardt       normal               ---       2     0
# 26                 Nick Edgar     critical            2.0 F2       2     0
# 27         Martin Aeschlimann        major            2.0 F2       2     0
# 28               Dirk Baeumer     critical            2.0 F2       2     0
# 29                 Nick Edgar       normal            2.0 F2       2     0
# ...                       ...          ...               ...     ...   ...
# 9970              Jared Burns       normal           3.0 RC2       3     0
# 9971             Saumit Sheth        major            3.1 M3       3     0
# 9972               Nick Edgar       normal            3.1 M4       3     0
# 9973       Curtis d'Entremont       normal            3.2 M5       3     0
# 9974             Darin Wright       normal           3.0 RC3       3     0
# 9975             Dejan Glozic       normal           3.0 RC3       3     0
# 9976            Darin Swanson       normal           3.0 RC4       3     0
# 9977          Michael Valenta        minor            3.1 M4       3     0
# 9978             Darin Wright  enhancement               3.1       3     0
# 9979             Darin Wright  enhancement            3.1 M3       3     0
# 9980          Rafal Sontowski       normal            3.1 M1       3     0
# 9981      Mikhail Khodjaiants  enhancement            3.1 M3       3     0
# 9982            Darin Swanson       normal            3.1 M1       3     0
# 9983                Ying Chen        major             3.0.1       3     0
# 9984                    Billy        major            3.1 M3       3     0
# 9985      Jörg von  Frantzius       normal             3.0.1       3     0
# 9986              Brad Clarke       normal            3.1 M5     3.1     0
# 9987              Jared Burns       normal               3.1       3     0
# 9988              Jared Burns       normal               3.1       3     0
# 9989              Jared Burns       normal               3.1       3     0
# 9990              Jared Burns       normal               3.1       3     0
# 9991              Jared Burns       normal               3.1       3     0
# 9992             Darin Wright  enhancement            3.1 M4       3     0
# 9993             David W Hare        major               3.1       3     0
# 9994            Darin Swanson       normal             3.0.1       3     0
# 9995         Saurabh Bagrodia        minor               3.1       3     0
# 9996               Paul Smith        minor            3.1 M3       3     0
# 9997  Thorbjørn Ravn Andersen  enhancement            3.1 M5       3     0
# 9998              DJ Houghton       normal            3.1 M2       3     0
# 9999            Darin Swanson       normal            3.1 M2       3     0
#
# [10000 rows x 21 columns]

# %%
# Finding the average number of comments per bug
average_comments = eclipse_df["Number of Comments"].mean()
average_comments
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-2b3137c7b9fe> in <module>
#       1 # Finding the average number of comments per bug
# ----> 2 average_comments = eclipse_df["Number of Comments"].mean()
#       3 average_comments
#
# NameError: name 'eclipse_df' is not defined

# %%
# Grouping the DataFrame by "Assignee"
assignee_group = eclipse_df.groupby("Assignee")

# Count how many of each component Assignees worked on and create DataFrame
assignee_work = pd.DataFrame(assignee_group["Component"].value_counts())
assignee_work.head()

# %%
# Rename the "Component" column to "Component Bug Count"

# %%
# Find the percentage of bugs overall fixed by each Assignee
total_bugs = assignee_group["Assignee"].count()
bugs_per_user = assignee_group["Assignee"].value_counts()

user_bug_percent = pd.DataFrame((bugs_per_user/total_bugs)*100)
user_bug_percent.head()

# %%
# Merge the "Percent of Total Bugs Assigned" into the DataFrame
assignee_work = assignee_work.merge(user_bug_percent, on="Assignee")

# Remove the extra columns
assignee_work = assignee_work[[
    "Assignee", "Percent of Total Bugs", "Component", "Component Bug Count"]]
assignee_work.head()
